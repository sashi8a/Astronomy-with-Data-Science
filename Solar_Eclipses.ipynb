# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_solar = pd.read_csv('solar.csv')[:239]
df_solar
# Out:
#      Catalog Number       Calendar Date Eclipse Time  Delta T (s)  \
# 0                 1       -1999 June 12     03:14:51        46438
# 1                 2    -1999 December 5     23:45:23        46426
# 2                 3        -1998 June 1     18:09:16        46415
# 3                 4   -1998 November 25     05:57:03        46403
# 4                 5      -1997 April 22     13:19:56        46393
# ..              ...                 ...          ...          ...
# 234             235  -1902 September 15     19:22:56        44101
# 235             236      -1901 March 13     00:23:10        44090
# 236             237   -1901 September 5     09:35:37        44078
# 237             238       -1900 March 1     01:25:12        44067
# 238             239     -1900 August 25     01:52:52        44055
#
#      Lunation Number  Saros Number Eclipse Type   Gamma  Eclipse Magnitude  \
# 0             -49456             5            T -0.2701             1.0733
# ...

# %%
sum_T = 0

for e in df_solar['Eclipse Type']:
    if e[0] =='T':
        sum_T+=1

sum_P = 0

for e in df_solar['Eclipse Type']:
    if e[0] =='P':
        sum_P+=1

sum_A = 0

for e in df_solar['Eclipse Type']:
    if e[0] =='A': 
        sum_A+=1     
        
sum_H = 0

for e in df_solar['Eclipse Type']:
    if e[0] =='H':
        sum_H+=1


        
totals = [sum_T,sum_P,sum_A,sum_H]


print(totals)
# Out:
# [62, 84, 71, 22]

# %%
types = ['Total','Partial', 'Annular','Hybrid']
c = ['red', 'yellow', 'green', 'blue']
plt.bar(types, totals, color = c, width = 0.6)
plt.xlabel('Type of Solar Eclipse')
plt.ylabel('Total Number of Eclipses')
plt.title('Distribution of Solar Eclipses')
plt.show()
