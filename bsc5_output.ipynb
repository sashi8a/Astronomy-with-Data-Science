# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# byte-by-byte delimiters
colspecs = [(0, 4), (4, 14), (14, 25), (25, 31), (31, 37),
(37, 41), (41, 42), (42, 43), (43, 44), (44, 49),
(49, 51), (51, 60), (60, 62), (62, 64), (64, 68),
(68, 69), (69, 71), (71, 73), (73, 75), (75, 77),
(77, 79), (79, 83), (83, 84), (84, 86), (86, 88),
(88, 90), (90, 96), (96, 102), (102, 107), (107, 108),
(108, 109), (109, 114), (114, 115), (115, 120), (120, 121),
(121, 126), (126, 127), (127, 147), (147, 148), (148, 154),
(154, 160), (160, 161), (161, 166), (166, 170), (170, 174),
(174, 176), (176, 179), (179, 180), (180, 184), (184, 190),
(190, 194), (194, 196), (196, 197)]
catalog = pd.read_fwf("bsc5.dat", header = None, colspecs = colspecs,
names = ["HR",
"Name",
"DM",
"HD",
"SAO",
"FK5",
"IRflag",
"r_IRflag",
"Multiple",
"ADS",
"ADScomp",
"VarID",
"RAh1900",
"RAm1900",
"RAs1900",
"DE-1900",
"DEd1900",
"DEm1900",
"DEs1900",
"RAh",
"RAm",
"RAs",
"DE-",
"DEd",
"DEm",
"DEs",
"GLON",
"GLAT",
"Vmag",
"n_Vmag",
"u_Vmag",
"B-V",
"u_B-V",
"U-B",
"u_U-B",
"R-I",
"n_R-I",
"SpType",
"n_SpType",
"pmRA",
"pmDE",
"n_Parallax",
"Parallax",
"RadVel",
"n_RadVel",
"l_RotVel",
"RotVel",
"u_RotVel",
"Dmag",
"Sep",
"MultID",
"MultCnt",
"NoteFlag"])
catalog.to_csv("bsc5.csv")
df = pd.read_csv("bsc5.csv")

# %%
df.shape
# Out:
# (9110, 54)

# %%
df.head(5)
# Out:
#    Unnamed: 0  HR       Name          DM     HD       SAO     FK5 IRflag  \
# 0           0   1        NaN  BD+44 4550    3.0   36042.0     NaN    NaN
# 1           1   2        NaN  BD-01 4525    6.0  128569.0     NaN    NaN
# 2           2   3  33    Psc  BD-06 6357   28.0  128572.0  1002.0      I
# 3           3   4  86    Peg  BD+12 5063   87.0   91701.0  2004.0    NaN
# 4           4   5        NaN  BD+57 2865  123.0   21085.0     NaN    NaN
#
#   r_IRflag Multiple  ...  RadVel n_RadVel l_RotVel  RotVel  u_RotVel  Dmag  \
# 0      NaN      NaN  ...   -18.0      NaN      NaN   195.0       NaN   4.2
# 1      NaN      NaN  ...    14.0        V      NaN     NaN       NaN   NaN
# 2      NaN      NaN  ...    -6.0     SB1O        <    17.0       NaN   2.5
# 3      NaN      NaN  ...    -2.0       V?      NaN     NaN       NaN   NaN
# 4      NaN      NaN  ...   -12.0        V      NaN     NaN       NaN   0.8
#
#     Sep  MultID  MultCnt  NoteFlag
# 0  21.6      AC      3.0       NaN
# 1   NaN     NaN      NaN       NaN
# 2   0.0     NaN      3.0         *
# 3   NaN     NaN      NaN       NaN
# 4   1.4     NaN      NaN         *
#
# [5 rows x 54 columns]

# %%
df.tail(5)
# Out:
#       Unnamed: 0    HR Name          DM        HD       SAO     FK5 IRflag  \
# 9105        9105  9106  NaN  CP-73 2346  225233.0  255629.0     NaN    NaN
# 9106        9106  9107  NaN  BD+33 4828  225239.0   53622.0  2002.0    NaN
# 9107        9107  9108  NaN  CP-72 2800  225253.0  255631.0  1001.0    NaN
# 9108        9108  9109  NaN  BD+25 5068  225276.0   73731.0     NaN      I
# 9109        9109  9110  NaN  BD+60 2667  225289.0   10962.0     NaN    NaN
#
#      r_IRflag Multiple  ...  RadVel n_RadVel l_RotVel  RotVel  u_RotVel  Dmag  \
# 9105      NaN      NaN  ...     8.0      NaN      NaN     NaN       NaN   NaN
# 9106      NaN      NaN  ...     4.0        V      NaN     NaN       NaN   NaN
# 9107      NaN      NaN  ...    -3.0        V      NaN     NaN       NaN   NaN
# 9108      NaN      NaN  ...    -5.0      NaN      NaN     NaN       NaN   4.5
# 9109      NaN      NaN  ...    14.0        V      NaN    50.0       NaN   NaN
#
#        Sep  MultID  MultCnt  NoteFlag
# 9105   NaN     NaN      NaN       NaN
# 9106   NaN     NaN      NaN       NaN
# 9107   NaN     NaN      NaN       NaN
# 9108  17.5     NaN      NaN       NaN
# 9109   NaN     NaN      NaN         *
#
# [5 rows x 54 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0          HR             HD            SAO          FK5  \
# count  9110.00000  9110.00000    9096.000000    9071.000000  3077.000000
# mean   4554.50000  4555.50000  107334.581794  134193.509536  1954.447514
# std    2629.97481  2629.97481   67739.321279   75516.511021  1209.016612
# min       0.00000     1.00000       3.000000     106.000000     1.000000
# 25%    2277.25000  2278.25000   44330.500000   71659.000000   820.000000
# 50%    4554.50000  4555.50000  103449.500000  131443.000000  2104.000000
# 75%    6831.75000  6832.75000  167648.750000  200666.500000  3046.000000
# max    9109.00000  9110.00000  225289.000000  258996.000000  3997.000000
#
#                 ADS      RAh1900      RAm1900      RAs1900      DEd1900  ...  \
# count   1435.000000  9096.000000  9096.000000  9096.000000  9096.000000  ...
# mean    8278.804878    11.555739    29.665347    29.990699    33.864886  ...
# std     4700.699670     6.787416    17.189771    17.301530    21.200809  ...
# min        1.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%     4154.500000     6.000000    15.000000    14.800000    16.000000  ...
# 50%     8406.000000    11.000000    30.000000    30.300000    33.000000  ...
# 75%    11822.500000    18.000000    45.000000    44.500000    50.000000  ...
# max    17175.000000    23.000000    59.000000    59.900000    89.000000  ...
#
#                U-B          R-I         pmRA         pmDE     Parallax  \
# count  7206.000000  2551.000000  9096.000000  9096.000000  3289.000000
# mean      0.374167     0.368491     0.001827    -0.019225     0.024512
# std       0.804599     0.458768     0.163218     0.138356     0.032329
# min      -1.110000    -0.530000    -3.646000    -5.813000    -0.032000
# 25%      -0.080000     0.020000    -0.024000    -0.031000     0.009000
# 50%       0.100000     0.310000    -0.002000    -0.008000     0.018000
# 75%       0.880000     0.570000     0.020000     0.007000     0.032000
# max       7.400000     3.710000     4.136000     3.208000     0.751000
#
#             RadVel       RotVel         Dmag          Sep      MultCnt
# count  9092.000000  3933.000000  2890.000000  2951.000000  1148.000000
# mean      0.593049    87.736079     3.537024    38.439410     3.710801
# std      23.635129    83.446089     2.788965    70.584513     1.367829
# min    -140.000000     0.000000     0.000000     0.000000     3.000000
# 25%     -14.000000    19.000000     1.000000     1.300000     3.000000
# 50%       0.000000    60.000000     3.200000    10.800000     3.000000
# 75%      15.000000   132.000000     5.700000    41.950000     4.000000
# max     289.000000   455.000000    13.800000  1480.000000    17.000000
#
# [8 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9110 entries, 0 to 9109
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  9110 non-null   int64
#  1   HR          9110 non-null   int64
#  2   Name        3157 non-null   object
#  3   DM          9096 non-null   object
#  4   HD          9096 non-null   float64
#  5   SAO         9071 non-null   float64
#  6   FK5         3077 non-null   float64
#  7   IRflag      1743 non-null   object
#  8   r_IRflag    84 non-null     object
#  9   Multiple    1577 non-null   object
#  10  ADS         1435 non-null   float64
#  11  ADScomp     403 non-null    object
#  12  VarID       2182 non-null   object
#  13  RAh1900     9096 non-null   float64
#  14  RAm1900     9096 non-null   float64
#  15  RAs1900     9096 non-null   float64
#  16  DE-1900     9096 non-null   object
#  17  DEd1900     9096 non-null   float64
#  18  DEm1900     9096 non-null   float64
#  19  DEs1900     9096 non-null   float64
#  20  RAh         9096 non-null   float64
#  21  RAm         9096 non-null   float64
#  22  RAs         9096 non-null   float64
#  23  DE-         9096 non-null   object
#  24  DEd         9096 non-null   float64
#  25  DEm         9096 non-null   float64
#  26  DEs         9096 non-null   float64
#  27  GLON        9096 non-null   float64
#  28  GLAT        9096 non-null   float64
#  29  Vmag        9096 non-null   float64
#  30  n_Vmag      306 non-null    object
#  31  u_Vmag      1 non-null      object
#  32  B-V         8786 non-null   float64
#  33  u_B-V       30 non-null     object
#  34  U-B         7206 non-null   float64
#  35  u_U-B       46 non-null     object
#  36  R-I         2551 non-null   float64
#  37  n_R-I       303 non-null    object
#  38  SpType      9096 non-null   object
#  39  n_SpType    427 non-null    object
#  40  pmRA        9096 non-null   float64
#  41  pmDE        9096 non-null   float64
#  42  n_Parallax  388 non-null    object
#  43  Parallax    3289 non-null   float64
#  44  RadVel      9092 non-null   float64
#  45  n_RadVel    4958 non-null   object
#  46  l_RotVel    724 non-null    object
#  47  RotVel      3933 non-null   float64
#  48  u_RotVel    284 non-null    object
#  49  Dmag        2890 non-null   float64
#  50  Sep         2951 non-null   float64
#  51  MultID      1114 non-null   object
#  52  MultCnt     1148 non-null   float64
#  53  NoteFlag    4477 non-null   object
# dtypes: float64(30), int64(2), object(22)
# memory usage: 3.8+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'HR', 'Name', 'DM', 'HD', 'SAO', 'FK5', 'IRflag',
#        'r_IRflag', 'Multiple', 'ADS', 'ADScomp', 'VarID', 'RAh1900', 'RAm1900',
#        'RAs1900', 'DE-1900', 'DEd1900', 'DEm1900', 'DEs1900', 'RAh', 'RAm',
#        'RAs', 'DE-', 'DEd', 'DEm', 'DEs', 'GLON', 'GLAT', 'Vmag', 'n_Vmag',
#        'u_Vmag', 'B-V', 'u_B-V', 'U-B', 'u_U-B', 'R-I', 'n_R-I', 'SpType',
#        'n_SpType', 'pmRA', 'pmDE', 'n_Parallax', 'Parallax', 'RadVel',
#        'n_RadVel', 'l_RotVel', 'RotVel', 'u_RotVel', 'Dmag', 'Sep', 'MultID',
#        'MultCnt', 'NoteFlag'],
#       dtype='object')

# %%
RA = (15*df['RAh']) + (15*df['RAm'])/60 + (15*df['RAs'])/3600

DEC = df['DEd'] + df['DEm']/60 + df['DEs']/3600

for i in range(len(DEC)):
    if df['DE-'][i]=='-':
        DEC[i]*=-1


Glon = df['GLON']
Glat = df['GLAT']

# %%
plt.figure(figsize = (16, 8.4))
plt.subplot(projection = "aitoff")
plt.title("All-sky Plot in Equatorial Coordinates")
plt.plot(RA, DEC, 'o', markersize = 1, alpha = 0.85, color = 'b')
plt.grid(True)
plt.savefig('all_sky_eq.pdf')
plt.show()

# %%
plt.figure(figsize = (16, 8.4))
plt.subplot(projection = "aitoff")
plt.title("All-sky Plot in Galactic Coordinates")
plt.plot(Glon, Glat, 'o', markersize = 1, alpha = 0.85, color = 'b')
plt.grid(True)
plt.savefig('all_sky_gal.pdf')
plt.show()
